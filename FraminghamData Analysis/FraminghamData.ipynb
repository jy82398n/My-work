# %%
import pandas as pd
import numpy as np
from numpy import nan
import seaborn as sns
import matplotlib.pyplot as plt 
plt.rc("font", size=14)
filename = "C:/Users/jyots/Desktop/jyots/datawarehouse/project/FraminghamData.csv"
farmDF = pd.read_csv(filename, sep=',', decimal='.',header = 0)
farmDF.head(5)
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)
type(farmDF)
farmDF.head(10)
# Out:
#     RANDID  SEX TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE CIGPDAY   BMI  DIAB  \
# 0  7081702    2     214   50  115.0   66.0         0       0  22.7     0
# 1  4266491    1     187   51  134.0   94.0         0       0  28.9     0
# 2  2407080    1     311   57  183.0  105.0         1      20  31.9     0
# 3  6153879    2     124   65  114.0   64.0         0       0  23.1     0
# 4  7611382    1     328   54  162.0   96.0         0       0  23.8     0
# 5  3594337    2     174   54  141.0   83.0         0       0  20.6     0
# 6  6874151    2     177   69  148.0   66.0         1      18  24.6     0
# 7  9576337    1     171   73  124.0   82.0         0       0  22.7     0
# 8  9040921    2     137   65  151.0   87.0         0       0  31.6     0
# 9  9471636    2     165   52  120.0   80.0         0       0  21.2     0
#
#       ...       TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  TIMECVD  TIMEDTH  \
# 0     ...         8766    8766      8766     8766      8766     8766     8766
# ...

# %%
farmDF.dtypes
# Out:
# RANDID           int64
# SEX              int64
# TOTCHOL         object
# AGE              int64
# SYSBP          float64
# DIABP          float64
# CURSMOKE         int64
# CIGPDAY         object
# BMI             object
# DIAB             int64
# PREVCHD          int64
# PREVAP           int64
# PREVMI           int64
# PREVSTRK         int64
# PREVHYP          int64
# TIME             int64
# PERIOD           int64
# HDLC            object
# LDLC            object
# DEATH            int64
# ANGINA           int64
# HOSPMI           int64
# MI_FCHD          int64
# ANYCHD           int64
# STROKE           int64
# CVD              int64
# HYPERTEN         int64
# TIMEAP           int64
# TIMEMI           int64
# TIMEMIFC         int64
# TIMECHD          int64
# TIMESTRK         int64
# TIMECVD          int64
# TIMEDTH          int64
# TIMEHYP          int64
# Unnamed: 35    float64
# Unnamed: 36    float64
# dtype: object

# %%
farmDF["HDLC"].unique()
# Out:
# array(['85', '22', '30', '44', '64', '26', '41', '77', '71', '95', '59',
#        '54', '42', '40', '32', '81', '33', '66', '76', '69', '39', '75',
#        '46', '89', '27', '101', '60', '50', '87', '67', '56', '63', '49',
#        '68', '31', '88', '28', '48', '73', '72', '25', '34', '90', '36',
#        '94', '43', '51', '57', '58', '115', '65', '61', '45', '29', '103',
#        '84', '53', '52', '37', '189', '91', '55', '47', '38', '35', '83',
#        '82', '93', '74', '80', '79', '86', '62', '92', '117', '70', '78',
#        '21', '24', '104', '141', '100', '20', '18', '118', '23', '97',
#        '138', '109', '11', '108', '121', '19', '122', '99', '106', '102',
#        '15', '112', '12', '16', '17', '14', '114', '10', '.'], dtype=object)

# %%
farmDF["CVD"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
farmDF["LDLC"].unique()
# Out:
# array(['20', '34', '44', '45', '51', '52', '58', '60', '62', '64', '65',
#        '67', '68', '69', '70', '71', '74', '76', '77', '78', '80', '81',
#        '83', '85', '86', '87', '88', '89', '90', '91', '92', '93', '94',
#        '95', '96', '97', '98', '99', '100', '101', '102', '103', '104',
#        '105', '106', '107', '108', '109', '110', '111', '112', '113',
#        '114', '115', '116', '117', '118', '119', '120', '121', '122',
#        '123', '124', '125', '126', '127', '128', '129', '130', '131',
#        '132', '133', '134', '135', '136', '137', '138', '139', '140',
#        '141', '142', '143', '144', '145', '146', '147', '148', '149',
#        '150', '151', '152', '153', '154', '155', '156', '157', '158',
#        '159', '160', '161', '162', '163', '164', '165', '166', '167',
#        '168', '169', '170', '171', '172', '173', '174', '175', '176',
#        '177', '178', '179', '180', '181', '182', '183', '184', '185',
# ...

# %%
farmDF=farmDF.dropna()
print(farmDF.shape)
print(list(farmDF.columns))
# Out:
# (0, 37)
# ['RANDID', 'SEX', 'TOTCHOL', 'AGE', 'SYSBP', 'DIABP', 'CURSMOKE', 'CIGPDAY', 'BMI', 'DIAB', 'PREVCHD', 'PREVAP', 'PREVMI', 'PREVSTRK', 'PREVHYP', 'TIME', 'PERIOD', 'HDLC', 'LDLC', 'DEATH', 'ANGINA', 'HOSPMI', 'MI_FCHD', 'ANYCHD', 'STROKE', 'CVD', 'HYPERTEN', 'TIMEAP', 'TIMEMI', 'TIMEMIFC', 'TIMECHD', 'TIMESTRK', 'TIMECVD', 'TIMEDTH', 'TIMEHYP', 'Unnamed: 35', 'Unnamed: 36']

# %%
farmDF['CVD'].value_counts()
# Out:
# 0    2497
# 1     737
# Name: CVD, dtype: int64

# %%
sns.countplot(x='CVD',data=farmDF)
plt.show()

# %%
farmDF.groupby("CVD").mean()
# Out:
#            RANDID       SEX        AGE       SYSBP      DIABP  CURSMOKE  \
# CVD
# 0    5.013367e+06  1.622347  59.492191  137.518622  81.301362  0.341610
# 1    5.060219e+06  1.430122  64.405699  149.379240  83.567164  0.351425
#
#          DIAB   PREVCHD    PREVAP    PREVMI     ...            TIMEAP  \
# CVD                                             ...
# 0    0.051662  0.044053  0.040449  0.002002     ...       8121.099319
# 1    0.166893  0.299864  0.189959  0.168250     ...       6365.981004
#
#           TIMEMI     TIMEMIFC      TIMECHD     TIMESTRK      TIMECVD  \
# CVD
# 0    8449.468562  8449.468562  8091.914297  8470.835803  8470.835803
# 1    6946.044776  6738.974220  5550.236092  6916.478969  4976.800543
#
#          TIMEDTH      TIMEHYP  Unnamed: 35  Unnamed: 36
# CVD
# 0    8473.834602  4322.794954          NaN          NaN
# 1    7695.678426  2212.786974          NaN          NaN
#
# [2 rows x 31 columns]

# %%
farmDF.groupby("CVD").median()
# Out:
#       RANDID  SEX  AGE  SYSBP  DIABP  CURSMOKE  DIAB  PREVCHD  PREVAP  PREVMI  \
# CVD
# 0    4990480    2   58  134.0   80.0         0     0        0       0       0
# 1    5146930    1   64  148.0   82.5         0     0        0       0       0
#
#         ...       TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  TIMECVD  \
# CVD     ...
# 0       ...         8766    8766      8766     8766      8766     8766
# 1       ...         7052    7570      7357     5921      7452     5410
#
#      TIMEDTH  TIMEHYP  Unnamed: 35  Unnamed: 36
# CVD
# 0       8766     4178          NaN          NaN
# 1       8423      747          NaN          NaN
#
# [2 rows x 31 columns]

# %%
farmDF['LDLC'].replace('.',nan, inplace=True)
farmDF['LDLC'] = farmDF['LDLC'].fillna(0).astype(np.int)
farmDF['HDLC'].replace('.',nan, inplace=True)
farmDF['HDLC'] = farmDF['HDLC'].fillna(0).astype(np.int)
cols=farmDF[["HDLC", "LDLC","CVD"]]

cols.groupby("CVD").mean()
# Out:
#           HDLC        LDLC
# CVD
# 0    47.038046  162.661193
# 1    41.644505  166.913161

# %%
cols.groupby("CVD").median()
# Out:
#      HDLC  LDLC
# CVD
# 0      48   168
# 1      41   173

# %%
plt.scatter(x=farmDF.HDLC,y= farmDF.AGE)
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

bp=farmDF.boxplot(column=['HDLC','LDLC'],showfliers =True,sym='b')

plt.show()

# %%
farmDF.groupby("SEX").mean()
# Out:
#            RANDID        AGE       SYSBP      DIABP  CURSMOKE      DIAB  \
# SEX
# 1    5.075724e+06  60.276596  139.280264  82.624358  0.388848  0.087307
# 2    4.986397e+06  60.856227  140.907269  81.230091  0.311064  0.071085
#
#       PREVCHD    PREVAP    PREVMI  PREVSTRK     ...            TIMEAP  \
# SEX                                             ...
# 1    0.129127  0.085106  0.066764  0.020543     ...       7527.447542
# 2    0.082843  0.066809  0.020310  0.020844     ...       7862.213789
#
#           TIMEMI     TIMEMIFC      TIMECHD     TIMESTRK      TIMECVD  \
# SEX
# 1    7815.080704  7748.035950  7219.644901  7982.268525  7341.327953
# 2    8319.402993  8286.677712  7726.166756  8214.478888  7917.343132
#
#          TIMEDTH      TIMEHYP  Unnamed: 35  Unnamed: 36
# SEX
# 1    8161.720470  3771.227439          NaN          NaN
# 2    8394.684661  3893.458044          NaN          NaN
#
# [2 rows x 33 columns]

# %%
#converting the datatype of HDLC object to int and replacing the null values with mean
#set(farmDF['HDLC'].tolist())

farmDF['HDLC'].replace(0,nan, inplace=True)
farmDF["HDLC"]=farmDF["HDLC"].fillna(farmDF["HDLC"].mean())
farmDF1 =  farmDF[['HDLC','LDLC']]

farmDF1.tail(10)
# Out:
#            HDLC        LDLC
# 3224  49.398466  176.511007
# 3225  49.398466  176.511007
# 3226  49.398466  176.511007
# 3227  49.398466  176.511007
# 3228  49.398466  176.511007
# 3229  49.398466  176.511007
# 3230  49.398466  176.511007
# 3231  49.398466  176.511007
# 3232  49.398466  176.511007
# 3233  49.398466  176.511007

# %%
#converting the datatype of LDLC (object to int) and replacing the null values with mean


farmDF['LDLC'].replace(0,nan, inplace=True)
farmDF["LDLC"]=farmDF["LDLC"].fillna(farmDF["LDLC"].mean())
farmDF1 =  farmDF[['HDLC','LDLC','CVD']]

farmDF1.tail(10)
# Out:
#            HDLC        LDLC  CVD
# 3224  49.398466  176.511007    0
# 3225  49.398466  176.511007    1
# 3226  49.398466  176.511007    0
# 3227  49.398466  176.511007    1
# 3228  49.398466  176.511007    0
# 3229  49.398466  176.511007    0
# 3230  49.398466  176.511007    0
# 3231  49.398466  176.511007    1
# 3232  49.398466  176.511007    1
# 3233  49.398466  176.511007    1

# %% [markdown]
# Two-Sample T-Test
# In this case I will test whether the means of two independent data samples associated
# In this case the hypothesis are:
# H0: The two means are equal i.e μ(LDL|CVD=0) =μ(LDL|CVD=1)
# Ha: The two means are not equal μ(LDL|CVD=0) ≠μ(LDL|CVD=1)
#
# Similarly for the HDLC
# and taking  α = 0.05

# %%
ds_0CVD = farmDF[farmDF.CVD == 0]
ds_1CVD = farmDF[farmDF.CVD == 1]
HDLC_mean = ds_0CVD["HDLC"].mean()
HDLC1_mean = ds_1CVD["HDLC"].mean()

print ("HDLC_mean (Mean):", HDLC_mean)
print ("HDLC1_mean (Mean):", HDLC1_mean)
# Out:
# HDLC_mean (Mean): 50.55944212080831
# HDLC1_mean (Mean): 45.4650102725331

# %%
import scipy.stats as stats

stats.ttest_ind(ds_0CVD["HDLC"],ds_1CVD["HDLC"])
# Out:
# Ttest_indResult(statistic=8.1649570659575677, pvalue=4.5596616211503163e-16)

# %%
LDLC_mean = ds_0CVD["LDLC"].mean()
LDLC1_mean = ds_1CVD["LDLC"].mean()

print ("LDLC_mean (Mean):", LDLC_mean)
print ("LDLC1_mean (Mean):", LDLC1_mean)
stats.ttest_ind(ds_0CVD["LDLC"],ds_1CVD["LDLC"])
# Out:
# LDLC_mean (Mean): 175.24387637413153
# LDLC1_mean (Mean): 180.8041226941888
# Ttest_indResult(statistic=-2.9435603303797291, pvalue=0.0032677146561694609)

# %% [markdown]
# As we can see that the means in both the cases are different
# Hence, we can see, the p-value is way smaller than 0.05
# and consequently p<α we reject the null hypothesis and say:
# "We have a statistically significant evidence to believe that HDLC and LDLC both are associated to CVD."
#
#
#
#
#
# Now, below is another way to check the association and later predicting the CVD on the baises of the feild in our model.

# %%
from sklearn.model_selection import train_test_split

trainDF, testDF = train_test_split(farmDF, test_size=0.3)
print("Training size: "+str(len(trainDF)))
print("Testing size: "+str(len(testDF)))
# Out:
# Training size: 2263
# Testing size: 971

# %%
cols=["HDLC", "LDLC","DIAB","HYPERTEN","AGE","DIABP","SYSBP"]
X=trainDF[cols]
Y=trainDF['CVD']
trainDF['CVD'].value_counts()
# Out:
# 0    1752
# 1     511
# Name: CVD, dtype: int64

# %%
import statsmodels.api as sm
log_mod=sm.Logit(exog=X,endog= Y)
result=log_mod.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.493248
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:                    CVD   No. Observations:                 2263
# Model:                          Logit   Df Residuals:                     2256
# Method:                           MLE   Df Model:                            6
# Date:                Mon, 11 Dec 2017   Pseudo R-squ.:                 0.07659
# Time:                        14:18:57   Log-Likelihood:                -1116.2
# converged:                       True   LL-Null:                       -1208.8
#                                         LLR p-value:                 2.714e-37
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# HDLC          -0.0368      0.004     -9.568      0.000      -0.044      -0.029
# ...

# %%
cols=["HDLC", "LDLC","HYPERTEN","AGE","DIABP","SYSBP","DIAB"]
#cols=["HDLC", "LDLC"]
data=farmDF[cols].values
print(data)
# Out:
# [[  85.           20.            0.         ...,   66.          115.            0.        ]
#  [  22.           34.            1.         ...,   94.          134.            0.        ]
#  [  30.           44.            1.         ...,  105.          183.            0.        ]
#  ...,
#  [  49.39846616  176.51100734    1.         ...,   93.5         196.5           0.        ]
#  [  49.39846616  176.51100734    1.         ...,   87.          157.            1.        ]
#  [  49.39846616  176.51100734    1.         ...,   70.          167.5           1.        ]]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import model_selection
from sklearn import metrics

lr = LogisticRegression(solver='liblinear')
predicted = model_selection.cross_val_predict(lr,data, farmDF['CVD'])
print (metrics.accuracy_score(farmDF['CVD'], predicted))
# Out:
# 0.777056277056

# %%
x = trainDF[cols].values
y = trainDF['CVD'].values

xTest = testDF[cols].values
yTest = testDF['CVD'].values

lr.fit(x,y)
print ("Coefficient: "+str(lr.coef_))
print ("Intercept: "+str(lr.intercept_))
print ("R-Squared: "+str(lr.score(xTest,yTest)))

predicted = lr.predict(xTest)
print (metrics.accuracy_score(yTest, predicted))
# Out:
# Coefficient: [[-0.02932182 -0.00084245  0.31816736  0.04775001 -0.0091127   0.01271408
#    0.7808557 ]]
# Intercept: [-4.01598851]
# R-Squared: 0.775489186406
# 0.775489186406

# %%
resultDF = testDF.assign(prediction=predicted)
cols1=["CVD","prediction"]
result=resultDF[cols1]
result.head(30)
# Out:
#       CVD  prediction
# 2284    0           0
# 2195    1           0
# 287     1           0
# 579     0           0
# 1104    0           0
# 3027    0           0
# 318     1           0
# 2918    1           0
# 1866    1           0
# 272     0           0
# 2670    0           0
# 962     0           0
# 82      0           0
# 1251    1           0
# 186     0           0
# 1111    0           0
# 2184    0           0
# 292     0           0
# 229     0           0
# 2086    0           0
# 1789    0           0
# 2649    0           0
# 2790    1           1
# 3225    1           0
# 1546    0           0
# 2016    1           0
# 1886    0           0
# 1890    0           0
# 1670    0           0
# 2167    1           0

# %%
lr.predict_proba(xTest)
# Out:
# array([[ 0.78820197,  0.21179803],
#        [ 0.58253362,  0.41746638],
#        [ 0.93128291,  0.06871709],
#        ...,
#        [ 0.82746147,  0.17253853],
#        [ 0.87157015,  0.12842985],
#        [ 0.89754086,  0.10245914]])
